# %%
from yahoodownloader import YahooDownloader
from preprocessors import FeatureEngineer
from models import DRLEnsembleAgent
import numpy as np
import pandas as pd

# %%
TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2021-10-01'
TEST_START_DATE = '2021-10-01'
TEST_END_DATE = '2023-03-01'

# %%
# TecDAX constituents at 2021/02
TECDAX_TICKER = [
    "ADV.DE",
    "AFX.DE",
    "AM3D.DE",
    "BC8.DE",
    "COK.DE",
    "DLG.DE",
    "DRI.DE",
    "DRW3.DE",
    "EVT.DE",
    "FNTN.DE",
    "GFT.DE",
    "JEN.DE",
    "MDG1.DE",
    "MOR.DE",
    "NDX1.DE",
    "NEM.DE",
    "O2D.DE",
    "PFV.DE",
    "QIA.DE",
    "RIB.DE",
    "S92.DE",
    "SANT.DE",
    "SOW.DE",
    "SRT3.DE",
    "UTDI.DE",
    "WAF.DE",
    "WDI.DE",
]

# Dow-Jones constituents at 2021/02
DOW_30_TICKER = [
    "AXP",
    "AMGN",
    "AAPL",
    "BA",
    "CAT",
    "CSCO",
    "CVX",
    "GS",
    "HD",
    "HON",
    "IBM",
    "INTC",
    "JNJ",
    "KO",
    "JPM",
    "MCD",
    "MMM",
    "MRK",
    "MSFT",
    "NKE",
    "PG",
    "TRV",
    "UNH",
    "CRM",
    "VZ",
    "V",
    "WBA",
    "WMT",
    "DIS",
    "DOW",
]

# DAX constituents at 2021/02
DAX_30_TICKER = [
    "DHER.DE",
    "RWE.DE",
    "FRE.DE",
    "MTX.DE",
    "MRK.DE",
    "LIN.DE",
    "ALV.DE",
    "VNA.DE",
    "EOAN.DE",
    "HEN3.DE",
    "DAI.DE",
    "DB1.DE",
    "DPW.DE",
    "DWNI.DE",
    "BMW.DE",
    "DTE.DE",
    "VOW3.DE",
    "MUV2.DE",
    "1COV.DE",
    "SAP.DE",
    "FME.DE",
    "BAS.DE",
    "BAYN.DE",
    "BEI.DE",
    "CON.DE",
    "SIE.DE",
    "ADS.DE",
    "HEI.DE",
    "DBK.DE",
    "IFX.DE",
]

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (97013, 8)

# %%
df.head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2010-01-04   7.622500   7.660714   7.585000   6.478997  493729600  AAPL
# 1  2010-01-04  56.630001  57.869999  56.560001  41.817787    5277400  AMGN
# 2  2010-01-04  40.810001  41.099998  40.389999  33.300190    6894300   AXP
# 3  2010-01-04  55.720001  56.389999  54.799999  43.777557    6186700    BA
# 4  2010-01-04  57.650002  59.189999  57.509998  40.523605    7325600   CAT
#
#    day
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0

# %%
INDICATORS = ["macd",
            "boll_ub",
            "boll_lb",
            "rsi_30",
            "cci_30",
            "dx_30",
            "close_30_sma",
            "close_60_sma",
        ]

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#              date        open        high         low      close    volume  \
# 2576   2010-05-11   29.809999   30.080000   29.549999  24.338903   9614100
# 52323  2017-03-06  113.250000  113.500000  112.669998  84.914627   4731900
# 22147  2013-01-15   26.830000   27.290001   26.830000  22.239416  48244500
# 35480  2014-11-11   33.360001   33.540001   33.200001  25.898684  19676600
# 56308  2017-09-19   62.996181   63.129772   62.671757  52.327702   7345746
#
#         tic  day      macd     rsi_30      cci_30      dx_30  turbulence
# 2576    UNH    1 -0.553362  43.609747  -77.041015  11.736397    0.000000
# 52323   CVX    0  0.033312  52.752707   25.758245   1.516814   10.443633
# 22147  MSFT    1 -0.088228  48.286417   37.726826   8.470751   30.472565
# 35480  INTC    1  0.103050  50.812898   27.156662  14.474299    9.657687
# 56308   MRK    1  0.739380  62.965176  142.875041  23.687492   33.538310

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 175

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
}

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  201.71829873833732
# ======Model training from:  2010-01-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_8
# ----------------------------------------
# | time/                 |              |
# |    fps                | 267          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -41.1        |
# |    explained_variance | 0.103        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -43.6        |
# |    reward             | -0.060437355 |
# |    std                | 1            |
# |    value_loss         | 1.81         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 272        |
# |    iterations         | 200        |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.151     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 35.6       |
# |    reward             | 0.96720177 |
# |    std                | 1          |
# |    value_loss         | 3.55       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 271        |
# |    iterations         | 300        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.202      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -44.5      |
# |    reward             | -2.9207852 |
# |    std                | 1          |
# |    value_loss         | 3.3        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 271         |
# |    iterations         | 400         |
# |    time_elapsed       | 7           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | -0.17       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | 106         |
# |    reward             | -0.11317777 |
# |    std                | 1           |
# |    value_loss         | 11.2        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 272        |
# |    iterations         | 500        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -191       |
# |    reward             | -1.0667822 |
# |    std                | 0.999      |
# |    value_loss         | 20.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 270        |
# |    iterations         | 600        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | -8.1       |
# |    reward             | 0.82612395 |
# |    std                | 0.999      |
# |    value_loss         | 0.0814     |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 271       |
# |    iterations         | 700       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -60.7     |
# |    reward             | 0.4820757 |
# |    std                | 0.999     |
# |    value_loss         | 2.52      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 272        |
# |    iterations         | 800        |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 87.6       |
# |    reward             | -2.7318401 |
# |    std                | 1          |
# |    value_loss         | 7.62       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 274        |
# |    iterations         | 900        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -488       |
# |    reward             | -1.7291757 |
# |    std                | 0.999      |
# |    value_loss         | 147        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 1000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.000504  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -420      |
# |    reward             | 1.5233274 |
# |    std                | 0.998     |
# |    value_loss         | 254       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 1100      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -260      |
# |    reward             | 4.6295805 |
# |    std                | 0.998     |
# |    value_loss         | 46.7      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 275         |
# |    iterations         | 1200        |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | -0.0236     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | -56         |
# |    reward             | -0.68659073 |
# |    std                | 0.997       |
# |    value_loss         | 2.62        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 274        |
# |    iterations         | 1300       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 66.5       |
# |    reward             | 0.20748325 |
# |    std                | 0.995      |
# |    value_loss         | 4.63       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 266         |
# |    iterations         | 1400        |
# |    time_elapsed       | 26          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | 104         |
# |    reward             | -0.30484968 |
# |    std                | 0.995       |
# |    value_loss         | 6.05        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 265        |
# |    iterations         | 1500       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 133        |
# |    reward             | -0.9375777 |
# |    std                | 0.997      |
# |    value_loss         | 11.7       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 1600     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -41.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -85.3    |
# |    reward             | 2.403133 |
# |    std                | 0.998    |
# |    value_loss         | 10.7     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 266       |
# |    iterations         | 1700      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 357       |
# |    reward             | 3.6846354 |
# |    std                | 0.998     |
# |    value_loss         | 82.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 1800      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.0457    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -49.5     |
# |    reward             | 0.5964555 |
# |    std                | 0.996     |
# |    value_loss         | 2.45      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 1900      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.0122    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 26.1      |
# |    reward             | 1.2792102 |
# |    std                | 0.994     |
# |    value_loss         | 1.49      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 46.9     |
# |    reward             | 0.987627 |
# |    std                | 0.994    |
# |    value_loss         | 2.99     |
# ------------------------------------
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.19482692731201365
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_7
# ----------------------------------
# | time/              |           |
# |    fps             | 284       |
# |    iterations      | 1         |
# |    time_elapsed    | 7         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 0.7777005 |
# ----------------------------------
# day: 2957, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4344775.43
# total_reward: 3344775.43
# total_cost: 404415.78
# total_trades: 82551
# Sharpe: 0.861
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014972338 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00036     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.03        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0222     |
# |    reward               | 0.8970171   |
# |    std                  | 1           |
# |    value_loss           | 11.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.014993474  |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.2        |
# |    explained_variance   | 0.0113       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 28.1         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0184      |
# |    reward               | -0.110915385 |
# |    std                  | 1            |
# |    value_loss           | 48.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.017535836 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | 0.00756     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0223     |
# |    reward               | 5.623673    |
# |    std                  | 1.01        |
# |    value_loss           | 44.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 5            |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0135560315 |
# |    clip_fraction        | 0.165        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.3        |
# |    explained_variance   | -0.0288      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 13.2         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.021       |
# |    reward               | -0.579131    |
# |    std                  | 1.01         |
# |    value_loss           | 26.7         |
# ------------------------------------------
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.31646577700907935
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_7
# day: 2957, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 6144769.95
# total_reward: 5144769.95
# total_cost: 999.00
# total_trades: 52383
# Sharpe: 0.976
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 186      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 11832    |
# | train/             |          |
# |    actor_loss      | 39.8     |
# |    critic_loss     | 193      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 8874     |
# |    reward          | 9.232039 |
# ---------------------------------
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71829873833732
# ======Model training from:  2010-01-01 to  2022-01-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_5
# -------------------------------------
# | time/                 |           |
# |    fps                | 272       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.402     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -17       |
# |    reward             | 0.3082029 |
# |    std                | 1         |
# |    value_loss         | 0.337     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 275        |
# |    iterations         | 200        |
# |    time_elapsed       | 3          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.00162   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -125       |
# |    reward             | -0.7104781 |
# |    std                | 1.01       |
# |    value_loss         | 12.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 275        |
# |    iterations         | 300        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 36.5       |
# |    reward             | -2.3362768 |
# |    std                | 1.01       |
# |    value_loss         | 2.48       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 276        |
# |    iterations         | 400        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 109        |
# |    reward             | -0.9410746 |
# |    std                | 1.01       |
# |    value_loss         | 11.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 276        |
# |    iterations         | 500        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.0059     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -16.2      |
# |    reward             | 0.71918684 |
# |    std                | 1.01       |
# |    value_loss         | 1.11       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 276      |
# |    iterations         | 600      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 259      |
# |    reward             | 7.09519  |
# |    std                | 1.01     |
# |    value_loss         | 47       |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 276         |
# |    iterations         | 700         |
# |    time_elapsed       | 12          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -63.3       |
# |    reward             | -0.12653017 |
# |    std                | 1.01        |
# |    value_loss         | 3.01        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 276       |
# |    iterations         | 800       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 155       |
# |    reward             | 0.9602341 |
# |    std                | 1.01      |
# |    value_loss         | 16.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 900       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -38.8     |
# |    reward             | 4.2264767 |
# |    std                | 1.01      |
# |    value_loss         | 3.44      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 1000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 20.5      |
# |    reward             | 0.4856404 |
# |    std                | 1.01      |
# |    value_loss         | 2.33      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 277          |
# |    iterations         | 1100         |
# |    time_elapsed       | 19           |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -41.5        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | 55.6         |
# |    reward             | 0.0031198268 |
# |    std                | 1.01         |
# |    value_loss         | 7.44         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 1200      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | 578       |
# |    reward             | 3.8589032 |
# |    std                | 1.01      |
# |    value_loss         | 214       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 277        |
# |    iterations         | 1300       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 31.2       |
# |    reward             | 0.89093906 |
# |    std                | 1.01       |
# |    value_loss         | 1          |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 277        |
# |    iterations         | 1400       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 59.3       |
# |    reward             | 0.13377361 |
# |    std                | 1.02       |
# |    value_loss         | 4.65       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 1500      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | -0.428    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 154       |
# |    reward             | 1.7787272 |
# |    std                | 1.02      |
# |    value_loss         | 16.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 277        |
# |    iterations         | 1600       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -0.00187   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 83.7       |
# |    reward             | -0.5431525 |
# |    std                | 1.02       |
# |    value_loss         | 9.33       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 1700      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 1.01e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -299      |
# |    reward             | 3.4060264 |
# |    std                | 1.02      |
# |    value_loss         | 55.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 277        |
# |    iterations         | 1800       |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -287       |
# |    reward             | -5.2009344 |
# |    std                | 1.02       |
# |    value_loss         | 50.1       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 1900     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -41.6    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 43.9     |
# |    reward             | 1.313449 |
# |    std                | 1.02     |
# |    value_loss         | 3.14     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 277        |
# |    iterations         | 2000       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 36.4       |
# |    reward             | -1.0251013 |
# |    std                | 1.02       |
# |    value_loss         | 1.39       |
# --------------------------------------
# ======A2C Validation from:  2022-01-03 to  2022-04-04
# A2C Sharpe Ratio:  -0.09321463054764681
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_5
# -----------------------------------
# | time/              |            |
# |    fps             | 293        |
# |    iterations      | 1          |
# |    time_elapsed    | 6          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.81082755 |
# -----------------------------------
# day: 3020, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4391549.31
# total_reward: 3391549.31
# total_cost: 431494.95
# total_trades: 84825
# Sharpe: 0.846
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.018268626 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.014      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.12        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0282     |
# |    reward               | -1.227424   |
# |    std                  | 1           |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017477373 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.000998   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0191     |
# |    reward               | -0.73162687 |
# |    std                  | 1           |
# |    value_loss           | 55          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 292        |
# |    iterations           | 4          |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01224987 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.00661   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 20.2       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0217    |
# |    reward               | -0.460874  |
# |    std                  | 1          |
# |    value_loss           | 39         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018438853 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0234     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.8         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0267     |
# |    reward               | -0.23445533 |
# |    std                  | 1           |
# |    value_loss           | 11.2        |
# -----------------------------------------
# ======PPO Validation from:  2022-01-03 to  2022-04-04
# PPO Sharpe Ratio:  -0.227293823451647
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_5
# day: 3020, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 7362359.49
# total_reward: 6362359.49
# total_cost: 1315.42
# total_trades: 30331
# Sharpe: 1.024
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 175        |
# |    time_elapsed    | 68         |
# |    total_timesteps | 12084      |
# | train/             |            |
# |    actor_loss      | 65         |
# |    critic_loss     | 645        |
# |    learning_rate   | 0.0005     |
# |    n_updates       | 9063       |
# |    reward          | -1.6449821 |
# -----------------------------------
# ======DDPG Validation from:  2022-01-03 to  2022-04-04
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71829873833732
# ======Model training from:  2010-01-01 to  2022-04-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_5
# --------------------------------------
# | time/                 |            |
# |    fps                | 279        |
# |    iterations         | 100        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.00102    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -41.8      |
# |    reward             | 0.04718798 |
# |    std                | 1          |
# |    value_loss         | 1.52       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 281       |
# |    iterations         | 200       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0149    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -6.57     |
# |    reward             | 0.7868907 |
# |    std                | 1         |
# |    value_loss         | 1.82      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 281        |
# |    iterations         | 300        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.166      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -35.1      |
# |    reward             | -3.6839542 |
# |    std                | 1          |
# |    value_loss         | 6.13       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 281       |
# |    iterations         | 400       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -24.1     |
# |    reward             | -2.186852 |
# |    std                | 1         |
# |    value_loss         | 8.44      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 273       |
# |    iterations         | 500       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -25.6     |
# |    reward             | -2.215946 |
# |    std                | 0.997     |
# |    value_loss         | 0.56      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 274        |
# |    iterations         | 600        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 260        |
# |    reward             | -4.5624886 |
# |    std                | 0.997      |
# |    value_loss         | 49.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 275       |
# |    iterations         | 700       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.00342   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -131      |
# |    reward             | 1.6298903 |
# |    std                | 0.997     |
# |    value_loss         | 13.6      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 276         |
# |    iterations         | 800         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | 0.0137      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | -169        |
# |    reward             | -0.11242312 |
# |    std                | 0.996       |
# |    value_loss         | 19.9        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 900       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 14        |
# |    reward             | -2.242492 |
# |    std                | 0.995     |
# |    value_loss         | 3.37      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 277       |
# |    iterations         | 1000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -0.333    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 67.4      |
# |    reward             | 1.3270613 |
# |    std                | 0.994     |
# |    value_loss         | 2.92      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 277        |
# |    iterations         | 1100       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0.00377    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -218       |
# |    reward             | -2.0049343 |
# |    std                | 0.996      |
# |    value_loss         | 43.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 277        |
# |    iterations         | 1200       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.0452    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | 0.963      |
# |    reward             | -2.5544212 |
# |    std                | 0.998      |
# |    value_loss         | 5.05       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 1300      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0.164     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 50        |
# |    reward             | 0.5564972 |
# |    std                | 1         |
# |    value_loss         | 1.76      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 278        |
# |    iterations         | 1400       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.35      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | -110       |
# |    reward             | 0.25669888 |
# |    std                | 1          |
# |    value_loss         | 8.76       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 278       |
# |    iterations         | 1500      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0413   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -11.9     |
# |    reward             | -2.100401 |
# |    std                | 1         |
# |    value_loss         | 0.581     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 279        |
# |    iterations         | 1600       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0.339      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -33.9      |
# |    reward             | -1.7717509 |
# |    std                | 0.998      |
# |    value_loss         | 0.931      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 279        |
# |    iterations         | 1700       |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 155        |
# |    reward             | 0.32285848 |
# |    std                | 0.999      |
# |    value_loss         | 25.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 279        |
# |    iterations         | 1800       |
# |    time_elapsed       | 32         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.0168    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 369        |
# |    reward             | -1.6798023 |
# |    std                | 0.999      |
# |    value_loss         | 100        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 279         |
# |    iterations         | 1900        |
# |    time_elapsed       | 33          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0.0363      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 4.81        |
# |    reward             | 0.047913052 |
# |    std                | 0.998       |
# |    value_loss         | 0.126       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 280        |
# |    iterations         | 2000       |
# ...
# |    reward             | -4.2881775 |
# |    std                | 1          |
# |    value_loss         | 4.27       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 232      |
# |    iterations         | 400      |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0.0541   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -5.67    |
# |    reward             | 1.476319 |
# |    std                | 1        |
# |    value_loss         | 10.1     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 232        |
# |    iterations         | 500        |
# |    time_elapsed       | 10         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -201       |
# |    reward             | -2.6535735 |
# |    std                | 1          |
# |    value_loss         | 27.2       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 600       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.0684   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 32.2      |
# |    reward             | 2.5684457 |
# |    std                | 0.998     |
# |    value_loss         | 18.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 232       |
# |    iterations         | 700       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.317    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -50.2     |
# |    reward             | 0.9362925 |
# |    std                | 0.999     |
# |    value_loss         | 1.65      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 236         |
# |    iterations         | 800         |
# |    time_elapsed       | 16          |
# |    total_timesteps    | 4000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 799         |
# |    policy_loss        | 84.3        |
# |    reward             | -0.26610866 |
# |    std                | 0.999       |
# |    value_loss         | 4.19        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 238          |
# |    iterations         | 900          |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -41.2        |
# |    explained_variance | -0.207       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | 140          |
# |    reward             | -0.007739221 |
# |    std                | 1            |
# |    value_loss         | 19.5         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 241         |
# |    iterations         | 1000        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0.0441      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | 79.1        |
# |    reward             | -0.22973067 |
# |    std                | 1           |
# |    value_loss         | 4.7         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 241       |
# |    iterations         | 1100      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -83.3     |
# |    reward             | 1.5503242 |
# |    std                | 0.998     |
# |    value_loss         | 9.87      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 240        |
# |    iterations         | 1200       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -236       |
# |    reward             | -4.7446103 |
# |    std                | 0.999      |
# |    value_loss         | 45.4       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 241        |
# |    iterations         | 1300       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.00947   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 29.9       |
# |    reward             | -0.9487681 |
# |    std                | 1          |
# |    value_loss         | 0.78       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 241        |
# |    iterations         | 1400       |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | -8.73      |
# |    reward             | -1.5993618 |
# |    std                | 0.999      |
# |    value_loss         | 0.369      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 242       |
# |    iterations         | 1500      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -131      |
# |    reward             | 5.4663453 |
# |    std                | 0.999     |
# |    value_loss         | 14.3      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 243         |
# |    iterations         | 1600        |
# |    time_elapsed       | 32          |
# |    total_timesteps    | 8000        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1599        |
# |    policy_loss        | -0.999      |
# |    reward             | -0.19805442 |
# |    std                | 1           |
# |    value_loss         | 2.75        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 245         |
# |    iterations         | 1700        |
# |    time_elapsed       | 34          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | 616         |
# |    reward             | -0.37118322 |
# |    std                | 0.999       |
# |    value_loss         | 254         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 245        |
# |    iterations         | 1800       |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 355        |
# |    reward             | -2.9047647 |
# |    std                | 0.997      |
# |    value_loss         | 208        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 244        |
# |    iterations         | 1900       |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 31.4       |
# |    reward             | 0.18435356 |
# |    std                | 0.996      |
# |    value_loss         | 0.597      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 245        |
# |    iterations         | 2000       |
# |    time_elapsed       | 40         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.00789   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 57.9       |
# |    reward             | -0.9518717 |
# |    std                | 0.997      |
# |    value_loss         | 2.73       |
# --------------------------------------
# ======A2C Validation from:  2022-07-06 to  2022-10-04
# A2C Sharpe Ratio:  -0.053250710044579194
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_5
# ----------------------------------
# | time/              |           |
# |    fps             | 272       |
# |    iterations      | 1         |
# |    time_elapsed    | 7         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.2315003 |
# ----------------------------------
# day: 3146, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4129393.59
# total_reward: 3129393.59
# total_cost: 460206.51
# total_trades: 87992
# Sharpe: 0.754
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 273        |
# |    iterations           | 2          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01561023 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.0255    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 4.55       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0261    |
# |    reward               | 3.7212992  |
# |    std                  | 1          |
# |    value_loss           | 13.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011566704 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.000326    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 43.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0184     |
# |    reward               | 3.9180868   |
# |    std                  | 1           |
# |    value_loss           | 79.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013511438 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.0021      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 36.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0204     |
# |    reward               | 1.1517987   |
# |    std                  | 1           |
# |    value_loss           | 87.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 274         |
# |    iterations           | 5           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018196506 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0762     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.99        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0218     |
# |    reward               | 1.0521512   |
# |    std                  | 1.01        |
# |    value_loss           | 33.7        |
# -----------------------------------------
# ======PPO Validation from:  2022-07-06 to  2022-10-04
# PPO Sharpe Ratio:  -0.2712716182753716
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_5
# day: 3146, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5507529.54
# total_reward: 4507529.54
# total_cost: 1897.55
# total_trades: 37941
# Sharpe: 0.870
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 172       |
# |    time_elapsed    | 73        |
# |    total_timesteps | 12588     |
# | train/             |           |
# |    actor_loss      | -8.96     |
# |    critic_loss     | 185       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9441      |
# |    reward          | 0.8336499 |
# ----------------------------------
# ======DDPG Validation from:  2022-07-06 to  2022-10-04
# ======Best Model Retraining from:  2010-01-01 to  2022-10-04
# ======Trading from:  2022-10-04 to  2023-01-04
# Ensemble Strategy took:  10.058670767148335  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-10-04  2022-01-03       DDPG   0.192077   0.185683    0.225868
# 1  189  2022-01-03  2022-03-31       DDPG   -0.29392   -0.25255     -0.1418
# 2  252  2022-03-31  2022-06-30        PPO  -0.334913  -0.323758   -0.357652
# 3  315  2022-06-30  2022-09-27       DDPG  -0.461999  -0.205301   -0.131556

# %%
import torch
torch.save(ensemble_agent, 'ensemble_agent.pt')

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = pd.concat([df_account_value,temp],ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.739577055871337

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2022-01-03           NaN  2022-01-03
# 1   1.000932e+06  2022-01-04      0.000932  2022-01-04
# 2   9.974004e+05  2022-01-05     -0.003528  2022-01-05
# 3   9.954190e+05  2022-01-06     -0.001987  2022-01-06
# 4   9.951867e+05  2022-01-07     -0.000233  2022-01-07

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %%
from plot import backtest_stats, get_baseline
import datetime
import matplotlib.pyplot as plt
# Out:
# /Users/omgodage/Desktop/College/sem 5/CS337/CS-337-project-main/venv/lib/python3.11/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.145239
# Cumulative returns    -0.145239
# Annual volatility      0.188900
# Sharpe ratio          -0.739577
# Calmar ratio          -0.567536
# Stability              0.400239
# Max drawdown          -0.255912
# Omega ratio            0.885277
# Sortino ratio         -1.002960
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.128654
# Daily value at risk   -0.024354
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%%**********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return         -0.094324
# Cumulative returns    -0.093968
# Annual volatility      0.198502
# Sharpe ratio          -0.402058
# Calmar ratio          -0.429901
# Stability              0.236972
# Max drawdown          -0.219408
# Omega ratio            0.936015
# Sortino ratio         -0.559755
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.014390
# Daily value at risk   -0.025326
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
print("df_dji: ", df_dji)
df_dji.to_csv("df_ndx+.csv")

df_account_value.to_csv('df_account_value.csv')
# Out:
# df_dji:             date           dji
# 0    2022-01-03  1.000000e+06
# 1    2022-01-04  1.005866e+06
# 2    2022-01-05  9.951360e+05
# 3    2022-01-06  9.904718e+05
# 4    2022-01-07  9.903404e+05
# ..          ...           ...
# 247  2022-12-27  9.086102e+05
# 248  2022-12-28  8.986103e+05
# 249  2022-12-29  9.080428e+05
# 250  2022-12-30  9.060324e+05
# 251  2023-01-03           NaN
#
# [252 rows x 2 columns]
# df_dji:                       dji
# date
# 2022-01-03  1.000000e+06
# 2022-01-04  1.005866e+06
# 2022-01-05  9.951360e+05
# 2022-01-06  9.904718e+05
# 2022-01-07  9.903404e+05
# ...                  ...
# 2022-12-27  9.086102e+05
# 2022-12-28  8.986103e+05
# 2022-12-29  9.080428e+05
# 2022-12-30  9.060324e+05
# 2023-01-03           NaN
#
# [252 rows x 1 columns]

# %%
# print("==============Compare to DJIA===========")
# %matplotlib inline
# # Dow Jones Index: ^DJI
# # NASDAQ 100: ^NDX
# backtest_plot(df_account_value, 
#               baseline_ticker = '^DJI', 
#               baseline_start = df_account_value.loc[0,'date'],
#               baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date': df_account_value['date'], 'ensemble': df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')

print("df_result_ensemble.columns: ", df_result_ensemble.columns)


print("df_trade_date: ", df_trade_date)
df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble: ", df_result_ensemble)
print("==============Compare to DJIA===========")
result = pd.DataFrame()
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
print("result: ", result)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
plt.savefig("plot_dji.jpg")
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date:         datadate
# 0    2021-10-04
# 1    2021-10-05
# 2    2021-10-06
# 3    2021-10-07
# 4    2021-10-08
# ..          ...
# 348  2023-02-22
# 349  2023-02-23
# 350  2023-02-24
# 351  2023-02-27
# 352  2023-02-28
#
# [353 rows x 1 columns]
# df_result_ensemble:                  ensemble
# date
# 2022-01-03  1.000000e+06
# 2022-01-04  1.000932e+06
# 2022-01-05  9.974004e+05
# 2022-01-06  9.954190e+05
# 2022-01-07  9.951867e+05
# ...                  ...
# 2022-12-27  8.597843e+05
# 2022-12-28  8.528634e+05
# 2022-12-29  8.580895e+05
# 2022-12-30  8.560809e+05
# 2023-01-03  8.547608e+05
#
# [252 rows x 1 columns]
# ==============Compare to DJIA===========
# result:                  ensemble           dji
# date
# 2022-01-03  1.000000e+06  1.000000e+06
# 2022-01-04  1.000932e+06  1.005866e+06
# 2022-01-05  9.974004e+05  9.951360e+05
# 2022-01-06  9.954190e+05  9.904718e+05
# 2022-01-07  9.951867e+05  9.903404e+05
# ...                  ...           ...
# 2022-12-27  8.597843e+05  9.086102e+05
# 2022-12-28  8.528634e+05  8.986103e+05
# 2022-12-29  8.580895e+05  9.080428e+05
# 2022-12-30  8.560809e+05  9.060324e+05
# 2023-01-03  8.547608e+05           NaN
#
# [252 rows x 2 columns]

# %% [markdown]
# # Individual Agents

# %%
individual_agent = DRLEnsembleAgent(df=processed,
                    train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                    val_test_period=(TEST_START_DATE,TEST_END_DATE),
                    rebalance_window=rebalance_window, 
                    validation_window=validation_window, 
                    **env_kwargs)
A2C_dummy_kwargs = {
    'n_steps': 5,
    'ent_coef': 0.005,
    'learning_rate': 0
    # 'learning_rate': 0.0007
}

PPO_dummy_kwargs = {
    "ent_coef":0.01,
    "n_steps": 2048,
    # "learning_rate": 0.00025,
    "learning_rate": 0,
    "batch_size": 128
}

DDPG_dummy_kwargs = {
    #"action_noise":"ornstein_uhlenbeck",
    "buffer_size": 10_000,
    # "learning_rate": 0.0000,
    "learning_rate": 0.0005,
    "batch_size": 64
}

dummy_time_dict = {
    'a2c': 0,
    'ppo': 0,
    'ddpg': 10_000
}
single_summary = individual_agent.run_ensemble_strategy(A2C_dummy_kwargs, PPO_dummy_kwargs, DDPG_dummy_kwargs, dummy_time_dict)
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = pd.concat([df_account_value,temp],ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))

df_account_value.head()

# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  201.71829873833732
# ======Model training from:  2010-01-01 to  2021-10-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_11
# ======A2C Validation from:  2021-10-04 to  2022-01-03
# A2C Sharpe Ratio:  0.2169690693684687
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_10
# ======PPO Validation from:  2021-10-04 to  2022-01-03
# PPO Sharpe Ratio:  0.10456086074639126
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_10
# day: 2957, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 5849102.28
# total_reward: 4849102.28
# total_cost: 999.00
# total_trades: 50269
# Sharpe: 0.912
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 169       |
# |    time_elapsed    | 69        |
# |    total_timesteps | 11832     |
# | train/             |           |
# |    actor_loss      | -7.54     |
# |    critic_loss     | 216       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 8874      |
# |    reward          | 10.067192 |
# ----------------------------------
# ======DDPG Validation from:  2021-10-04 to  2022-01-03
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71829873833732
# ======Model training from:  2010-01-01 to  2022-01-03
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_8
# ======A2C Validation from:  2022-01-03 to  2022-04-04
# A2C Sharpe Ratio:  -0.06625738565439507
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_8
# ======PPO Validation from:  2022-01-03 to  2022-04-04
# PPO Sharpe Ratio:  -0.17377415802049492
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_8
# day: 3020, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 6799774.03
# total_reward: 5799774.03
# total_cost: 1004.81
# total_trades: 24160
# Sharpe: 0.929
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 172        |
# |    time_elapsed    | 70         |
# |    total_timesteps | 12084      |
# | train/             |            |
# |    actor_loss      | -25        |
# |    critic_loss     | 497        |
# |    learning_rate   | 0.0005     |
# |    n_updates       | 9063       |
# |    reward          | -3.4670694 |
# -----------------------------------
# ======DDPG Validation from:  2022-01-03 to  2022-04-04
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71829873833732
# ======Model training from:  2010-01-01 to  2022-04-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_8
# ======A2C Validation from:  2022-04-04 to  2022-07-06
# A2C Sharpe Ratio:  -0.24939295269471648
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_252_8
# ======PPO Validation from:  2022-04-04 to  2022-07-06
# PPO Sharpe Ratio:  -0.14050652410008582
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_252_8
# day: 3083, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4705742.98
# total_reward: 3705742.98
# total_cost: 1214.91
# total_trades: 46267
# Sharpe: 0.893
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 184       |
# |    time_elapsed    | 67        |
# |    total_timesteps | 12336     |
# | train/             |           |
# |    actor_loss      | -83       |
# |    critic_loss     | 625       |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 9252      |
# |    reward          | 2.0952282 |
# ----------------------------------
# ======DDPG Validation from:  2022-04-04 to  2022-07-06
# ======Best Model Retraining from:  2010-01-01 to  2022-07-06
# ======Trading from:  2022-07-06 to  2022-10-04
# ============================================
# turbulence_threshold:  201.71829873833732
# ======Model training from:  2010-01-01 to  2022-07-06
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_315_8
# ======A2C Validation from:  2022-07-06 to  2022-10-04
# A2C Sharpe Ratio:  -0.21906048742462259
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_8
# ======PPO Validation from:  2022-07-06 to  2022-10-04
# PPO Sharpe Ratio:  -0.2801166169304931
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_8
# day: 3146, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4204318.19
# total_reward: 3204318.19
# total_cost: 1354.17
# total_trades: 28433
# Sharpe: 0.717
# =================================
# -----------------------------------
# | time/              |            |
# |    episodes        | 4          |
# |    fps             | 173        |
# |    time_elapsed    | 72         |
# |    total_timesteps | 12588      |
# | train/             |            |
# |    actor_loss      | -34.4      |
# |    critic_loss     | 152        |
# |    learning_rate   | 0.0005     |
# |    n_updates       | 9441       |
# |    reward          | -3.2262201 |
# -----------------------------------
# ======DDPG Validation from:  2022-07-06 to  2022-10-04
# ======Best Model Retraining from:  2010-01-01 to  2022-10-04
# ======Trading from:  2022-10-04 to  2023-01-04
# Ensemble Strategy took:  5.306417000293732  minutes
# Sharpe Ratio:  -0.7357369983358488
# <Axes: >

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
print("df_dji: ", df_dji)
df_dji.to_csv("df_ndx.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
print("df_dji: ", df_dji)
df_dji.to_csv("df_ndx+.csv")

df_account_value.to_csv('df_account_value.csv')

df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date': df_account_value['date'], 'ensemble': df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')

print("df_result_ensemble.columns: ", df_result_ensemble.columns)
print("df_trade_date: ", df_trade_date)
df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble: ", df_result_ensemble)
print("==============Compare to DJIA===========")
result = pd.DataFrame()
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
print("result: ", result)
result.to_csv("result_ddpg.csv")
result.columns = ['ddpg', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot()
plt.savefig("plot_ddpg_dji.jpg")
# Out:
# df_dji:             date           dji
# 0    2022-01-03  1.000000e+06
# 1    2022-01-04  1.005866e+06
# 2    2022-01-05  9.951360e+05
# 3    2022-01-06  9.904718e+05
# 4    2022-01-07  9.903404e+05
# ..          ...           ...
# 247  2022-12-27  9.086102e+05
# 248  2022-12-28  8.986103e+05
# 249  2022-12-29  9.080428e+05
# 250  2022-12-30  9.060324e+05
# 251  2023-01-03           NaN
#
# [252 rows x 2 columns]
# df_dji:                       dji
# date
# 2022-01-03  1.000000e+06
# 2022-01-04  1.005866e+06
# 2022-01-05  9.951360e+05
# 2022-01-06  9.904718e+05
# 2022-01-07  9.903404e+05
# ...                  ...
# 2022-12-27  9.086102e+05
# 2022-12-28  8.986103e+05
# 2022-12-29  9.080428e+05
# 2022-12-30  9.060324e+05
# 2023-01-03           NaN
#
# [252 rows x 1 columns]
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date:         datadate
# 0    2021-10-04
# 1    2021-10-05
# 2    2021-10-06
# 3    2021-10-07
# 4    2021-10-08
# ..          ...
# 348  2023-02-22
# 349  2023-02-23
# 350  2023-02-24
# 351  2023-02-27
# 352  2023-02-28
#
# [353 rows x 1 columns]
# df_result_ensemble:                    ensemble
# date
# 2022-01-03  1000000.000000
# 2022-01-04   999663.971991
# 2022-01-05   997738.180517
# 2022-01-06   994289.820133
# 2022-01-07   993939.528284
# ...                    ...
# 2022-12-27   869968.616135
# 2022-12-28   861390.826248
# 2022-12-29   868261.368668
# 2022-12-30   866087.928231
# 2023-01-03   861427.432755
#
# [252 rows x 1 columns]
# ==============Compare to DJIA===========
# result:                    ensemble           dji
# date
# 2022-01-03  1000000.000000  1.000000e+06
# 2022-01-04   999663.971991  1.005866e+06
# 2022-01-05   997738.180517  9.951360e+05
# 2022-01-06   994289.820133  9.904718e+05
# 2022-01-07   993939.528284  9.903404e+05
# ...                    ...           ...
# 2022-12-27   869968.616135  9.086102e+05
# 2022-12-28   861390.826248  8.986103e+05
# 2022-12-29   868261.368668  9.080428e+05
# 2022-12-30   866087.928231  9.060324e+05
# 2023-01-03   861427.432755           NaN
#
# [252 rows x 2 columns]
